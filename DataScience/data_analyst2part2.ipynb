# %%
import pandas as pd
import numpy as np


import plotly.express as px
import seaborn as sns

# %%
penguins_df= sns.load_dataset('penguins')

# %%
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins_df['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
sns.barplot(data=penguins_df,x='species',y='body_mass_g')
# Out:
# <AxesSubplot: xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxenplot(data=penguins_df,x='species',y='body_mass_g')
# Out:
# <AxesSubplot: xlabel='species', ylabel='body_mass_g'>

# %%
sns.catplot(data=penguins_df,x='species',y='body_mass_g')

# %%
sns.displot(data=penguins_df,x='species',y='body_mass_g')

# %%
sns.dogplot(data=penguins_df,x='species',y='body_mass_g')

# %%
sns.ecdfplot(data=penguins_df,hue='species',x='body_mass_g')
# Out:
# <AxesSubplot: xlabel='body_mass_g', ylabel='Proportion'>

# %%
sns.kdeplot(data=penguins_df,y='body_mass_g',x='flipper_length_mm')
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.pointplot(data=penguins_df,x='species',y='body_mass_g')
# Out:
# <AxesSubplot: xlabel='species', ylabel='body_mass_g'>

# %%
sns.regplot(data=penguins_df,x='species',y='body_mass_g')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# c:\Users\Yash\Desktop\python data science\DataScience\data_analyst2part2.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Yash/Desktop/python%20data%20science/DataScience/data_analyst2part2.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> sns.regplot(data=penguins_df,x='species',y='body_mass_g')
#
# File c:\Users\Yash\miniconda3\lib\site-packages\seaborn\regression.py:850, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     848 scatter_kws["marker"] = marker
#     849 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 850 plotter.plot(ax, scatter_kws, line_kws)
#     851 return ax
#
# ...

# %%
sns.stripplot(data=penguins_df,x='species',y='body_mass_g')
# Out:
# <AxesSubplot: xlabel='species', ylabel='body_mass_g'>
